# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import re
import nltk
import string
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px
import ipywidgets as widgets
import nltk
from pandas_profiling import ProfileReport
nltk.download('stopwords')
from tqdm.notebook import tqdm, trange
from plotly.offline import init_notebook_mode
from ipywidgets import interact, interactive, fixed, interact_manual
from datetime import datetime
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from statsmodels.graphics.gofplots import qqplot
from scipy import stats
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.feature_extraction.text import TfidfVectorizer
pd.set_option('display.max_columns', None)
# Out:
# <style>.container { width:100% !important; }</style>
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Humberto\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_colwidth', None)

# %%
data = pd.read_csv('full_join_mayflower_top_10.csv')
data
# Out:
# C:\Users\Humberto\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning:
#
# Columns (17,24,25) have mixed types.Specify dtype option on import or set low_memory=False.
#               id                            listing_url       scrape_id  \
# 0         634424    https://www.airbnb.com/rooms/634424  20210705235432
# 1         634424    https://www.airbnb.com/rooms/634424  20210705235432
# 2         634424    https://www.airbnb.com/rooms/634424  20210705235432
# 3         634424    https://www.airbnb.com/rooms/634424  20210705235432
# 4         634424    https://www.airbnb.com/rooms/634424  20210705235432
# ...          ...                                    ...             ...
# 241260  50827534  https://www.airbnb.com/rooms/50827534  20210705235432
# 241261  50827534  https://www.airbnb.com/rooms/50827534  20210705235432
# 241262  50827534  https://www.airbnb.com/rooms/50827534  20210705235432
# 241263  50827534  https://www.airbnb.com/rooms/50827534  20210705235432
# 241264  50827534  https://www.airbnb.com/rooms/50827534  20210705235432
#
#        last_scraped                                name  \
# 0        2021-07-07  In the heart of San Gabriel Valley
# 1        2021-07-07  In the heart of San Gabriel Valley
# 2        2021-07-07  In the heart of San Gabriel Valley
# 3        2021-07-07  In the heart of San Gabriel Valley
# 4        2021-07-07  In the heart of San Gabriel Valley
# ...             ...                                 ...
# 241260   2021-07-07                            安静舒适快乐之家
# 241261   2021-07-07                            安静舒适快乐之家
# 241262   2021-07-07                            安静舒适快乐之家
# 241263   2021-07-07                            安静舒适快乐之家
# 241264   2021-07-07                            安静舒适快乐之家
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      description  \
# 0       Private bedroom & bathroom available in 2 story house w/large window and natural light facing spacious backyard complete with gazebo and lush vegetation.Very close to Kaiser Permanente and perfect for the medical professional seeking proximity to workplace. Great for students who attend any of our local colleges including Cal Poly Pomona, Cal State LA, and Claremont Colleges. Also ideal for any traveler wishing to be in central location as close to downtown LA as it is to Pasadena or Long Beach.<br /><br /><b>The space</b><br />Room available: Bedroom. Separate private bath. Only shared when there are two simultaneous reservations. Clean, comfortable and chic in a contemporary single family home.<br /><br />Full use of kitchen, access  to the lovely, whimsical garden. A great and peaceful place to read a book, work or simply relax. When in season, please help yourself to my pomegranates, lemons, figs, guavas and apples as well as any veggies or herbs growing in the garden.<br /><br />T
# 1       Private bedroom & bathroom available in 2 story house w/large window and natural light facing spacious backyard complete with gazebo and lush vegetation.Very close to Kaiser Permanente and perfect for the medical professional seeking proximity to workplace. Great for students who attend any of our local colleges including Cal Poly Pomona, Cal State LA, and Claremont Colleges. Also ideal for any traveler wishing to be in central location as close to downtown LA as it is to Pasadena or Long Beach.<br /><br /><b>The space</b><br />Room available: Bedroom. Separate private bath. Only shared when there are two simultaneous reservations. Clean, comfortable and chic in a contemporary single family home.<br /><br />Full use of kitchen, access  to the lovely, whimsical garden. A great and peaceful place to read a book, work or simply relax. When in season, please help yourself to my pomegranates, lemons, figs, guavas and apples as well as any veggies or herbs growing in the garden.<br /><br />T
# 2            https://a0.muscache.com/im/users/3159772/profile_pic/1344128669/original.jpg?aki_policy=profile_x_medium
# 3            https://a0.muscache.com/im/users/3159772/profile_pic/1344128669/original.jpg?aki_policy=profile_x_medium
# 4            https://a0.muscache.com/im/users/3159772/profile_pic/1344128669/original.jpg?aki_policy=profile_x_medium
# ...                                                                                                               ...
# 241260  https://a0.muscache.com/im/pictures/user/760f35e2-fb98-4b06-bad8-ce6e2fcbb183.jpg?aki_policy=profile_x_medium
# 241261  https://a0.muscache.com/im/pictures/user/760f35e2-fb98-4b06-bad8-ce6e2fcbb183.jpg?aki_policy=profile_x_medium
# 241262  https://a0.muscache.com/im/pictures/user/760f35e2-fb98-4b06-bad8-ce6e2fcbb183.jpg?aki_policy=profile_x_medium
# 241263  https://a0.muscache.com/im/pictures/user/760f35e2-fb98-4b06-bad8-ce6e2fcbb183.jpg?aki_policy=profile_x_medium
# 241264  https://a0.muscache.com/im/pictures/user/760f35e2-fb98-4b06-bad8-ce6e2fcbb183.jpg?aki_policy=profile_x_medium
#
#        host_neighbourhood  host_listings_count  host_total_listings_count  \
# 0            Baldwin Park                  1.0                        1.0
# 1            Baldwin Park                  1.0                        1.0
# 2            Baldwin Park                  1.0                        1.0
# 3            Baldwin Park                  1.0                        1.0
# 4            Baldwin Park                  1.0                        1.0
# ...                   ...                  ...                        ...
# 241260                NaN                  0.0                        0.0
# 241261                NaN                  0.0                        0.0
# 241262                NaN                  0.0                        0.0
# 241263                NaN                  0.0                        0.0
# 241264                NaN                  0.0                        0.0
#
#                           host_verifications host_has_profile_pic  \
# 0       ['email', 'phone', 'reviews', 'kba']                 True
# 1       ['email', 'phone', 'reviews', 'kba']                 True
# 2       ['email', 'phone', 'reviews', 'kba']                 True
# 3       ['email', 'phone', 'reviews', 'kba']                 True
# 4       ['email', 'phone', 'reviews', 'kba']                 True
# ...                                      ...                  ...
# 241260                    ['email', 'phone']                 True
# 241261                    ['email', 'phone']                 True
# 241262                    ['email', 'phone']                 True
# 241263                    ['email', 'phone']                 True
# 241264                    ['email', 'phone']                 True
#
#        host_identity_verified                            neighbourhood  \
# 0                        True  Baldwin Park, California, United States
# 1                        True  Baldwin Park, California, United States
# 2                        True  Baldwin Park, California, United States
# 3                        True  Baldwin Park, California, United States
# 4                        True  Baldwin Park, California, United States
# ...                       ...                                      ...
# 241260                   True                                      NaN
# 241261                   True                                      NaN
# 241262                   True                                      NaN
# 241263                   True                                      NaN
# 241264                   True                                      NaN
#
#        neighbourhood_cleansed neighbourhood_group_cleansed   latitude  \
# 0                Baldwin Park                 Other Cities  34.071100
# 1                Baldwin Park                 Other Cities  34.071100
# 2                Baldwin Park                 Other Cities  34.071100
# 3                Baldwin Park                 Other Cities  34.071100
# 4                Baldwin Park                 Other Cities  34.071100
# ...                       ...                          ...        ...
# 241260            Temple City                 Other Cities  34.120046
# 241261            Temple City                 Other Cities  34.120046
# 241262            Temple City                 Other Cities  34.120046
# 241263            Temple City                 Other Cities  34.120046
# 241264            Temple City                 Other Cities  34.120046
#
#         longitude          property_type     room_type  accommodates  \
# 0      -117.97292  Private room in house  Private room             2
# 1      -117.97292  Private room in house  Private room             2
# 2      -117.97292  Private room in house  Private room             2
# 3      -117.97292  Private room in house  Private room             2
# 4      -117.97292  Private room in house  Private room             2
# ...           ...                    ...           ...           ...
# 241260 -118.06585  Private room in villa  Private room             2
# 241261 -118.06585  Private room in villa  Private room             2
# 241262 -118.06585  Private room in villa  Private room             2
# 241263 -118.06585  Private room in villa  Private room             2
# 241264 -118.06585  Private room in villa  Private room             2
#
#         bathrooms  bathrooms_text  bedrooms  beds  \
# 0             NaN             1.5       1.0   1.0
# 1             NaN             1.5       1.0   1.0
# 2             NaN             1.5       1.0   1.0
# 3             NaN             1.5       1.0   1.0
# 4             NaN             1.5       1.0   1.0
# ...           ...             ...       ...   ...
# 241260        NaN             1.0       1.0   1.0
# 241261        NaN             1.0       1.0   1.0
# 241262        NaN             1.0       1.0   1.0
# 241263        NaN             1.0       1.0   1.0
# 241264        NaN             1.0       1.0   1.0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           amenities  \
# 0                                                                                                                                                                                                                                                                                  ["Oven", "Heating", "Stove", "Dishwasher", "Extra pillows and blankets", "Hair dryer", "Hot water", "Dishes and silverware", "Coffee maker", "Iron", "Essentials", "Backyard", "Hangers", "Kitchen", "Indoor fireplace", "Cooking basics", "Wifi", "Refrigerator", "Free street parking", "Carbon monoxide alarm", "Smoke alarm", "Air conditioning", "Long term stays allowed"]
# 1                                                                                                                                                                                                                                                                                  ["Oven", "Heating", "Stove", "Dishwasher", "Extra pillows and blankets", "Hair dryer", "Hot water", "Dishes and silverware", "Coffee maker", "Iron", "Essentials", "Backyard", "Hangers", "Kitchen", "Indoor fireplace", "Cooking basics", "Wifi", "Refrigerator", "Free street parking", "Carbon monoxide alarm", "Smoke alarm", "Air conditioning", "Long term stays allowed"]
# 2                                                                                                                                                                                                                                                                                  ["Oven", "Heating", "Stove", "Dishwasher", "Extra pillows and blankets", "Hair dryer", "Hot water", "Dishes and silverware", "Coffee maker", "Iron", "Essentials", "Backyard", "Hangers", "Kitchen", "Indoor fireplace", "Cooking basics", "Wifi", "Refrigerator", "Free street parking", "Carbon monoxide alarm", "Smoke alarm", "Air conditioning", "Long term stays allowed"]
# 3                                                                                                                                                                                                                                                                                  ["Oven", "Heating", "Stove", "Dishwasher", "Extra pillows and blankets", "Hair dryer", "Hot water", "Dishes and silverware", "Coffee maker", "Iron", "Essentials", "Backyard", "Hangers", "Kitchen", "Indoor fireplace", "Cooking basics", "Wifi", "Refrigerator", "Free street parking", "Carbon monoxide alarm", "Smoke alarm", "Air conditioning", "Long term stays allowed"]
# 4                                                                                                                                                                                                                                                                                  ["Oven", "Heating", "Stove", "Dishwasher", "Extra pillows and blankets", "Hair dryer", "Hot water", "Dishes and silverware", "Coffee maker", "Iron", "Essentials", "Backyard", "Hangers", "Kitchen", "Indoor fireplace", "Cooking basics", "Wifi", "Refrigerator", "Free street parking", "Carbon monoxide alarm", "Smoke alarm", "Air conditioning", "Long term stays allowed"]
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 241260  ["Washer", "Oven", "Microwave", "Dryer", "Security cameras on property", "Heating", "Stove", "TV", "Extra pillows and blankets", "Ethernet connection", "Hot water", "Hot water kettle", "Dishes and silverware", "Shampoo", "Lock on bedroom door", "Essentials", "Free parking on premises", "Backyard", "Hangers", "Kitchen", "First aid kit", "Shower gel", "Bathtub", "Cooking basics", "Long term stays allowed", "Private entrance", "Wifi", "Children\u2019s books and toys", "Refrigerator", "Single level home", "Bed linens", "Free street parking", "Lockbox", "Carbon monoxide alarm", "Smoke alarm", "Air conditioning", "Fire extinguisher"]
# 241261  ["Washer", "Oven", "Microwave", "Dryer", "Security cameras on property", "Heating", "Stove", "TV", "Extra pillows and blankets", "Ethernet connection", "Hot water", "Hot water kettle", "Dishes and silverware", "Shampoo", "Lock on bedroom door", "Essentials", "Free parking on premises", "Backyard", "Hangers", "Kitchen", "First aid kit", "Shower gel", "Bathtub", "Cooking basics", "Long term stays allowed", "Private entrance", "Wifi", "Children\u2019s books and toys", "Refrigerator", "Single level home", "Bed linens", "Free street parking", "Lockbox", "Carbon monoxide alarm", "Smoke alarm", "Air conditioning", "Fire extinguisher"]
# 241262  ["Washer", "Oven", "Microwave", "Dryer", "Security cameras on property", "Heating", "Stove", "TV", "Extra pillows and blankets", "Ethernet connection", "Hot water", "Hot water kettle", "Dishes and silverware", "Shampoo", "Lock on bedroom door", "Essentials", "Free parking on premises", "Backyard", "Hangers", "Kitchen", "First aid kit", "Shower gel", "Bathtub", "Cooking basics", "Long term stays allowed", "Private entrance", "Wifi", "Children\u2019s books and toys", "Refrigerator", "Single level home", "Bed linens", "Free street parking", "Lockbox", "Carbon monoxide alarm", "Smoke alarm", "Air conditioning", "Fire extinguisher"]
# 241263  ["Washer", "Oven", "Microwave", "Dryer", "Security cameras on property", "Heating", "Stove", "TV", "Extra pillows and blankets", "Ethernet connection", "Hot water", "Hot water kettle", "Dishes and silverware", "Shampoo", "Lock on bedroom door", "Essentials", "Free parking on premises", "Backyard", "Hangers", "Kitchen", "First aid kit", "Shower gel", "Bathtub", "Cooking basics", "Long term stays allowed", "Private entrance", "Wifi", "Children\u2019s books and toys", "Refrigerator", "Single level home", "Bed linens", "Free street parking", "Lockbox", "Carbon monoxide alarm", "Smoke alarm", "Air conditioning", "Fire extinguisher"]
# 241264  ["Washer", "Oven", "Microwave", "Dryer", "Security cameras on property", "Heating", "Stove", "TV", "Extra pillows and blankets", "Ethernet connection", "Hot water", "Hot water kettle", "Dishes and silverware", "Shampoo", "Lock on bedroom door", "Essentials", "Free parking on premises", "Backyard", "Hangers", "Kitchen", "First aid kit", "Shower gel", "Bathtub", "Cooking basics", "Long term stays allowed", "Private entrance", "Wifi", "Children\u2019s books and toys", "Refrigerator", "Single level home", "Bed linens", "Free street parking", "Lockbox", "Carbon monoxide alarm", "Smoke alarm", "Air conditioning", "Fire extinguisher"]
#
#         price.x  minimum_nights.x  maximum_nights.x  minimum_minimum_nights  \
# 0            78                 2               180                       2
# 1            78                 2               180                       2
# 2            78                 2               180                       2
# 3            78                 2               180                       2
# 4            78                 2               180                       2
# ...         ...               ...               ...                     ...
# 241260       64                 1                30                       1
# 241261       64                 1                30                       1
# 241262       64                 1                30                       1
# 241263       64                 1                30                       1
# 241264       64                 1                30                       1
#
#         maximum_minimum_nights  minimum_maximum_nights  \
# 0                            2                     180
# 1                            2                     180
# 2                            2                     180
# 3                            2                     180
# 4                            2                     180
# ...                        ...                     ...
# 241260                       1                    1125
# 241261                       1                    1125
# 241262                       1                    1125
# 241263                       1                    1125
# 241264                       1                    1125
#
#         maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                          180                     2.0
# 1                          180                     2.0
# 2                          180                     2.0
# 3                          180                     2.0
# 4                          180                     2.0
# ...                        ...                     ...
# 241260                    1125                     1.0
# 241261                    1125                     1.0
# 241262                    1125                     1.0
# 241263                    1125                     1.0
# 241264                    1125                     1.0
#
#         maximum_nights_avg_ntm  calendar_updated  has_availability  \
# 0                          180               NaN              True
# 1                          180               NaN              True
# 2                          180               NaN              True
# 3                          180               NaN              True
# 4                          180               NaN              True
# ...                        ...               ...               ...
# 241260                    1125               NaN              True
# 241261                    1125               NaN              True
# 241262                    1125               NaN              True
# 241263                    1125               NaN              True
# 241264                    1125               NaN              True
#
#         availability_30  availability_60  availability_90  availability_365  \
# 0                    17               47               77               352
# 1                    17               47               77               352
# 2                    17               47               77               352
# 3                    17               47               77               352
# 4                    17               47               77               352
# ...                 ...              ...              ...               ...
# 241260               16               46               76               166
# 241261               16               46               76               166
# 241262               16               46               76               166
# 241263               16               46               76               166
# 241264               16               46               76               166
#
#        calendar_last_scraped  number_of_reviews  number_of_reviews_ltm  \
# 0                 2021-07-07                  8                      0
# 1                 2021-07-07                  8                      0
# 2                 2021-07-07                  8                      0
# 3                 2021-07-07                  8                      0
# 4                 2021-07-07                  8                      0
# ...                      ...                ...                    ...
# 241260            2021-07-07                  0                      0
# 241261            2021-07-07                  0                      0
# 241262            2021-07-07                  0                      0
# 241263            2021-07-07                  0                      0
# 241264            2021-07-07                  0                      0
#
#         number_of_reviews_l30d first_review last_review  review_scores_rating  \
# 0                            0   2015-03-11  2014-06-08                   5.0
# 1                            0   2015-03-11  2014-06-08                   5.0
# 2                            0   2015-03-11  2014-06-08                   5.0
# 3                            0   2015-03-11  2014-06-08                   5.0
# 4                            0   2015-03-11  2014-06-08                   5.0
# ...                        ...          ...         ...                   ...
# 241260                       0          NaN         NaN                   NaN
# 241261                       0          NaN         NaN                   NaN
# 241262                       0          NaN         NaN                   NaN
# 241263                       0          NaN         NaN                   NaN
# 241264                       0          NaN         NaN                   NaN
#
#         review_scores_accuracy  review_scores_cleanliness  \
# 0                          5.0                        5.0
# 1                          5.0                        5.0
# 2                          5.0                        5.0
# 3                          5.0                        5.0
# 4                          5.0                        5.0
# ...                        ...                        ...
# 241260                     NaN                        NaN
# 241261                     NaN                        NaN
# 241262                     NaN                        NaN
# 241263                     NaN                        NaN
# 241264                     NaN                        NaN
#
#         review_scores_checkin  review_scores_communication  \
# 0                         5.0                          5.0
# 1                         5.0                          5.0
# 2                         5.0                          5.0
# 3                         5.0                          5.0
# 4                         5.0                          5.0
# ...                       ...                          ...
# 241260                    NaN                          NaN
# 241261                    NaN                          NaN
# 241262                    NaN                          NaN
# 241263                    NaN                          NaN
# 241264                    NaN                          NaN
#
#         review_scores_location  review_scores_value  license  \
# 0                          5.0                 4.88      NaN
# 1                          5.0                 4.88      NaN
# 2                          5.0                 4.88      NaN
# 3                          5.0                 4.88      NaN
# 4                          5.0                 4.88      NaN
# ...                        ...                  ...      ...
# 241260                     NaN                  NaN      NaN
# 241261                     NaN                  NaN      NaN
# 241262                     NaN                  NaN      NaN
# 241263                     NaN                  NaN      NaN
# 241264                     NaN                  NaN      NaN
#
#         instant_bookable  calculated_host_listings_count  \
# 0                  False                               2
# 1                  False                               2
# 2                  False                               2
# 3                  False                               2
# 4                  False                               2
# ...                  ...                             ...
# 241260              True                               2
# 241261              True                               2
# 241262              True                               2
# 241263              True                               2
# 241264              True                               2
#
#         calculated_host_listings_count_entire_homes  \
# 0                                                 0
# 1                                                 0
# 2                                                 0
# 3                                                 0
# 4                                                 0
# ...                                             ...
# 241260                                            0
# 241261                                            0
# 241262                                            0
# 241263                                            0
# 241264                                            0
#
#         calculated_host_listings_count_private_rooms  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  2
# ...                                              ...
# 241260                                             2
# 241261                                             2
# 241262                                             2
# 241263                                             2
# 241264                                             2
#
#         calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 0                                                 0                0.1
# 1                                                 0                0.1
# 2                                                 0                0.1
# 3                                                 0                0.1
# 4                                                 0                0.1
# ...                                             ...                ...
# 241260                                            0                NaN
# 241261                                            0                NaN
# 241262                                            0                NaN
# 241263                                            0                NaN
# 241264                                            0                NaN
#
#               date  available  price.y  adjusted_price  minimum_nights.y  \
# 0       2021-07-07      False     78.0            78.0                 2
# 1       2021-07-08      False     78.0            78.0                 2
# 2       2021-07-09      False     78.0            78.0                 2
# 3       2021-07-10      False     78.0            78.0                 2
# 4       2021-07-11      False     78.0            78.0                 2
# ...            ...        ...      ...             ...               ...
# 241260  2022-07-02      False     80.0            80.0                 1
# 241261  2022-07-03      False     80.0            80.0                 1
# 241262  2022-07-04      False     80.0            80.0                 1
# 241263  2022-07-05      False     80.0            80.0                 1
# 241264  2022-07-06      False     80.0            80.0                 1
#
#         maximum_nights.y
# 0                    180
# 1                    180
# 2                    180
# 3                    180
# 4                    180
# ...                  ...
# 241260              1125
# 241261              1125
# 241262              1125
# 241263              1125
# 241264              1125
#
# [241265 rows x 80 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241265 entries, 0 to 241264
# Data columns (total 80 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   id                                            241265 non-null  int64
#  1   listing_url                                   241265 non-null  object
#  2   scrape_id                                     241265 non-null  int64
#  3   last_scraped                                  241265 non-null  object
#  4   name                                          241265 non-null  object
#  5   description                                   211700 non-null  object
#  6   neighborhood_overview                         129210 non-null  object
#  7   picture_url                                   241265 non-null  object
#  8   host_id                                       241265 non-null  int64
#  9   host_url                                      241265 non-null  object
#  10  host_name                                     240535 non-null  object
#  11  host_since                                    240535 non-null  object
#  12  host_location                                 238345 non-null  object
#  13  host_about                                    118260 non-null  object
#  14  host_response_time                            168995 non-null  object
#  15  host_response_rate                            168995 non-null  float64
#  16  host_acceptance_rate                          175200 non-null  float64
#  17  host_is_superhost                             240535 non-null  object
#  18  host_thumbnail_url                            240535 non-null  object
#  19  host_picture_url                              240535 non-null  object
#  20  host_neighbourhood                            133955 non-null  object
#  21  host_listings_count                           240535 non-null  float64
#  22  host_total_listings_count                     240535 non-null  float64
#  23  host_verifications                            241265 non-null  object
#  24  host_has_profile_pic                          240535 non-null  object
#  25  host_identity_verified                        240535 non-null  object
#  26  neighbourhood                                 129210 non-null  object
#  27  neighbourhood_cleansed                        241265 non-null  object
#  28  neighbourhood_group_cleansed                  241265 non-null  object
#  29  latitude                                      241265 non-null  float64
#  30  longitude                                     241265 non-null  float64
#  31  property_type                                 241265 non-null  object
#  32  room_type                                     241265 non-null  object
#  33  accommodates                                  241265 non-null  int64
#  34  bathrooms                                     0 non-null       float64
#  35  bathrooms_text                                237980 non-null  float64
#  36  bedrooms                                      222650 non-null  float64
#  37  beds                                          239075 non-null  float64
#  38  amenities                                     241265 non-null  object
#  39  price.x                                       241265 non-null  int64
#  40  minimum_nights.x                              241265 non-null  int64
#  41  maximum_nights.x                              241265 non-null  int64
#  42  minimum_minimum_nights                        241265 non-null  int64
#  43  maximum_minimum_nights                        241265 non-null  int64
#  44  minimum_maximum_nights                        241265 non-null  int64
#  45  maximum_maximum_nights                        241265 non-null  int64
#  46  minimum_nights_avg_ntm                        241265 non-null  float64
#  47  maximum_nights_avg_ntm                        241265 non-null  int64
#  48  calendar_updated                              0 non-null       float64
#  49  has_availability                              241265 non-null  bool
#  50  availability_30                               241265 non-null  int64
#  51  availability_60                               241265 non-null  int64
#  52  availability_90                               241265 non-null  int64
#  53  availability_365                              241265 non-null  int64
#  54  calendar_last_scraped                         241265 non-null  object
#  55  number_of_reviews                             241265 non-null  int64
#  56  number_of_reviews_ltm                         241265 non-null  int64
#  57  number_of_reviews_l30d                        241265 non-null  int64
#  58  first_review                                  194545 non-null  object
#  59  last_review                                   194545 non-null  object
#  60  review_scores_rating                          194545 non-null  float64
#  61  review_scores_accuracy                        191990 non-null  float64
#  62  review_scores_cleanliness                     191990 non-null  float64
#  63  review_scores_checkin                         191990 non-null  float64
#  64  review_scores_communication                   191990 non-null  float64
#  65  review_scores_location                        191990 non-null  float64
#  66  review_scores_value                           191990 non-null  float64
#  67  license                                       0 non-null       float64
#  68  instant_bookable                              241265 non-null  bool
#  69  calculated_host_listings_count                241265 non-null  int64
#  70  calculated_host_listings_count_entire_homes   241265 non-null  int64
#  71  calculated_host_listings_count_private_rooms  241265 non-null  int64
#  72  calculated_host_listings_count_shared_rooms   241265 non-null  int64
#  73  reviews_per_month                             194545 non-null  float64
#  74  date                                          241265 non-null  object
#  75  available                                     241265 non-null  bool
#  76  price.y                                       241262 non-null  float64
#  77  adjusted_price                                241262 non-null  float64
#  78  minimum_nights.y                              241265 non-null  int64
#  79  maximum_nights.y                              241265 non-null  int64
# dtypes: bool(3), float64(23), int64(25), object(29)
# memory usage: 142.4+ MB

# %%
profile = ProfileReport(data)
profile.to_file(output_file="data.html")

# %%
data = data.drop(columns=['listing_url', 'picture_url', 'host_url', 'host_picture_url', 'host_verifications', 'host_location', 'host_response_time', 'host_neighbourhood', 'host_name', 'host_about', 'host_acceptance_rate', 'host_total_listings_count', 'host_listings_count', 'host_is_superhost', 'neighbourhood_group_cleansed', 'neighbourhood', 'neighborhood_overview', 'calendar_last_scraped', 'date', 'last_scraped', 'license', 'bathrooms', 'calendar_updated', 
                          'reviews_per_month', 'review_scores_value', 'review_scores_location', 'review_scores_communication', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_accuracy', 'host_response_rate','price.x', 'price.y'])

# %%
data = data[data['adjusted_price'].notna()]

# %% [markdown]
# # Outliers handling

# %%
data = data[data['adjusted_price'] < 200]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 209643 entries, 0 to 241264
# Data columns (total 47 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   id                                            209643 non-null  int64
#  1   scrape_id                                     209643 non-null  int64
#  2   name                                          209643 non-null  object
#  3   description                                   181903 non-null  object
#  4   host_id                                       209643 non-null  int64
#  5   host_since                                    209498 non-null  object
#  6   host_thumbnail_url                            209498 non-null  object
#  7   host_has_profile_pic                          209498 non-null  object
#  8   host_identity_verified                        209498 non-null  object
#  9   neighbourhood_cleansed                        209643 non-null  object
#  10  latitude                                      209643 non-null  float64
#  11  longitude                                     209643 non-null  float64
#  12  property_type                                 209643 non-null  object
#  13  room_type                                     209643 non-null  object
#  14  accommodates                                  209643 non-null  int64
#  15  bathrooms_text                                206723 non-null  float64
#  16  bedrooms                                      192429 non-null  float64
#  17  beds                                          207818 non-null  float64
#  18  amenities                                     209643 non-null  object
#  19  minimum_nights.x                              209643 non-null  int64
#  20  maximum_nights.x                              209643 non-null  int64
#  21  minimum_minimum_nights                        209643 non-null  int64
#  22  maximum_minimum_nights                        209643 non-null  int64
#  23  minimum_maximum_nights                        209643 non-null  int64
#  24  maximum_maximum_nights                        209643 non-null  int64
#  25  minimum_nights_avg_ntm                        209643 non-null  float64
#  26  maximum_nights_avg_ntm                        209643 non-null  int64
#  27  has_availability                              209643 non-null  bool
#  28  availability_30                               209643 non-null  int64
#  29  availability_60                               209643 non-null  int64
#  30  availability_90                               209643 non-null  int64
#  31  availability_365                              209643 non-null  int64
#  32  number_of_reviews                             209643 non-null  int64
#  33  number_of_reviews_ltm                         209643 non-null  int64
#  34  number_of_reviews_l30d                        209643 non-null  int64
#  35  first_review                                  168322 non-null  object
#  36  last_review                                   168322 non-null  object
#  37  review_scores_rating                          168322 non-null  float64
#  38  instant_bookable                              209643 non-null  bool
#  39  calculated_host_listings_count                209643 non-null  int64
#  40  calculated_host_listings_count_entire_homes   209643 non-null  int64
#  41  calculated_host_listings_count_private_rooms  209643 non-null  int64
#  42  calculated_host_listings_count_shared_rooms   209643 non-null  int64
#  43  available                                     209643 non-null  bool
#  44  adjusted_price                                209643 non-null  float64
#  45  minimum_nights.y                              209643 non-null  int64
#  46  maximum_nights.y                              209643 non-null  int64
# dtypes: bool(3), float64(8), int64(24), object(12)
# memory usage: 72.6+ MB

# %%
sns.pairplot(data)

# %% [markdown]
# # SPLITS

# %%
df, validation_df  = train_test_split(data,
                                test_size=0.25,
                                random_state = 101)

# %%
df_train, df_test  = train_test_split(df,
                                test_size=0.25,
                                random_state = 101)

# %% [markdown]
# # EDA

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117924 entries, 204766 to 59795
# Data columns (total 47 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   id                                            117924 non-null  int64
#  1   scrape_id                                     117924 non-null  int64
#  2   name                                          117924 non-null  object
#  3   description                                   102284 non-null  object
#  4   host_id                                       117924 non-null  int64
#  5   host_since                                    117843 non-null  object
#  6   host_thumbnail_url                            117843 non-null  object
#  7   host_has_profile_pic                          117843 non-null  object
#  8   host_identity_verified                        117843 non-null  object
#  9   neighbourhood_cleansed                        117924 non-null  object
#  10  latitude                                      117924 non-null  float64
#  11  longitude                                     117924 non-null  float64
#  12  property_type                                 117924 non-null  object
#  13  room_type                                     117924 non-null  object
#  14  accommodates                                  117924 non-null  int64
#  15  bathrooms_text                                116281 non-null  float64
#  16  bedrooms                                      108253 non-null  float64
#  17  beds                                          116929 non-null  float64
#  18  amenities                                     117924 non-null  object
#  19  minimum_nights.x                              117924 non-null  int64
#  20  maximum_nights.x                              117924 non-null  int64
#  21  minimum_minimum_nights                        117924 non-null  int64
#  22  maximum_minimum_nights                        117924 non-null  int64
#  23  minimum_maximum_nights                        117924 non-null  int64
#  24  maximum_maximum_nights                        117924 non-null  int64
#  25  minimum_nights_avg_ntm                        117924 non-null  float64
#  26  maximum_nights_avg_ntm                        117924 non-null  int64
#  27  has_availability                              117924 non-null  bool
#  28  availability_30                               117924 non-null  int64
#  29  availability_60                               117924 non-null  int64
#  30  availability_90                               117924 non-null  int64
#  31  availability_365                              117924 non-null  int64
#  32  number_of_reviews                             117924 non-null  int64
#  33  number_of_reviews_ltm                         117924 non-null  int64
#  34  number_of_reviews_l30d                        117924 non-null  int64
#  35  first_review                                  94700 non-null   object
#  36  last_review                                   94700 non-null   object
#  37  review_scores_rating                          94700 non-null   float64
#  38  instant_bookable                              117924 non-null  bool
#  39  calculated_host_listings_count                117924 non-null  int64
#  40  calculated_host_listings_count_entire_homes   117924 non-null  int64
#  41  calculated_host_listings_count_private_rooms  117924 non-null  int64
#  42  calculated_host_listings_count_shared_rooms   117924 non-null  int64
#  43  available                                     117924 non-null  bool
#  44  adjusted_price                                117924 non-null  float64
#  45  minimum_nights.y                              117924 non-null  int64
#  46  maximum_nights.y                              117924 non-null  int64
# dtypes: bool(3), float64(8), int64(24), object(12)
# memory usage: 40.8+ MB

# %%
df_train.describe()
# Out:
#                  id     scrape_id       host_id       latitude      longitude  \
# count  1.179240e+05  1.179240e+05  1.179240e+05  117924.000000  117924.000000
# mean   3.298724e+07  2.021071e+13  1.669295e+08      34.113924    -118.028743
# std    1.323902e+07  2.037118e+01  1.185271e+08       0.028522       0.029999
# min    6.344240e+05  2.021071e+13  4.992440e+05      34.045550    -118.080860
# 25%    2.184331e+07  2.021071e+13  6.161775e+07      34.096530    -118.052760
# 50%    3.483937e+07  2.021071e+13  1.503653e+08      34.114410    -118.030280
# 75%    4.526896e+07  2.021071e+13  2.722021e+08      34.136270    -118.010510
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        1.000000
# 75%                                        4.000000
# max                                       38.000000
#
#        calculated_host_listings_count_shared_rooms  adjusted_price  \
# count                                117924.000000   117924.000000
# mean                                      0.192336       82.313261
# std                                       0.908651       41.905526
# min                                       0.000000       25.000000
# 25%                                       0.000000       50.000000
# 50%                                       0.000000       71.000000
# 75%                                       0.000000      100.000000
# max                                       6.000000      199.000000
#
#        minimum_nights.y  maximum_nights.y
# count     117924.000000     117924.000000
# mean          10.267172        792.940351
# std           36.579568        478.322853
# min            1.000000          1.000000
# 25%            1.000000        320.000000
# 50%            2.000000       1125.000000
# 75%            7.000000       1125.000000
# max          730.000000       1125.000000

# %%
plt.figure(figsize = (15, 8))
sns.distplot(df_train['adjusted_price'])
plt.title('Price distribution')
plt.show()

plt.figure(figsize = (15, 8))
sns.distplot((df_train['adjusted_price']-np.mean(df_train['adjusted_price'])) / np.std(df_train['adjusted_price']))
plt.title('Price distribution converted to z')
plt.show()
# Out:
# C:\Users\Humberto\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# C:\Users\Humberto\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
#qqplot
qqplot(df_train['adjusted_price'])

# %% [markdown]
# # Looks like price distribution is roughly Gaussian

# %%
df_train[df_train['bedrooms'] == 0].head()
# Out:
# Empty DataFrame
# Columns: [id, scrape_id, name, description, host_id, host_since, host_thumbnail_url, host_has_profile_pic, host_identity_verified, neighbourhood_cleansed, latitude, longitude, property_type, room_type, accommodates, bathrooms_text, bedrooms, beds, amenities, minimum_nights.x, maximum_nights.x, minimum_minimum_nights, maximum_minimum_nights, minimum_maximum_nights, maximum_maximum_nights, minimum_nights_avg_ntm, maximum_nights_avg_ntm, has_availability, availability_30, availability_60, availability_90, availability_365, number_of_reviews, number_of_reviews_ltm, number_of_reviews_l30d, first_review, last_review, review_scores_rating, instant_bookable, calculated_host_listings_count, calculated_host_listings_count_entire_homes, calculated_host_listings_count_private_rooms, calculated_host_listings_count_shared_rooms, available, adjusted_price, minimum_nights.y, maximum_nights.y]
# Index: []

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df_train.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Columns with a lot of missing data:

# %%
years_of_first_review = pd.DataFrame({
    'year of first review':pd.to_datetime(df_train['first_review'], format='%Y-%m-%d', errors='coerce').dt.year.fillna(0),
    'adjusted_price': df_train['adjusted_price']
})
plt.figure(figsize=(12,4))

sns.countplot(x="year of first review", data=years_of_first_review)
plt.title('Row count')
plt.show()

plt.figure(figsize=(12,8))
sns.boxplot(data=years_of_first_review,orient='v', x = 'year of first review', y = 'adjusted_price')
plt.title('Years of first review and price')
plt.show()

# %%
na_or_not = lambda x: 'na' if x else 'value'

first_review_error_status= pd.DataFrame({
    'first review error status':df_train['first_review'].isna().apply(na_or_not),
    'adjusted_price': df_train['adjusted_price']
})

plt.figure(figsize=(12,3))
sns.countplot(y='first review error status', data=first_review_error_status, orient='h')
plt.title('Row count')
plt.show()

plt.figure(figsize=(12,3))
sns.boxplot(data=first_review_error_status,orient='h', y = 'first review error status', x = 'adjusted_price')
plt.title('Price distribution for na and notna values in first_review column')
plt.show()

# %%
plt.figure(figsize=(10,5))
g = sns.FacetGrid(first_review_error_status, hue="first review error status", height = 5, aspect = 2)
g.map(sns.kdeplot, "adjusted_price")
plt.legend()
plt.title('Price distribution for na and notna values in first_review column')
plt.show()

# %%
years_of_last_review = pd.DataFrame({
    'year of last review':pd.to_datetime(df_train['last_review'], format='%Y-%m-%d', errors='coerce').dt.year.fillna(0),
    'adjusted_price': df_train['adjusted_price']
})

plt.figure(figsize=(12,4))
sns.countplot(x="year of last review", data=years_of_last_review)
plt.title('Row count')
plt.show()

plt.figure(figsize=(12,8))
sns.boxplot(data=years_of_last_review,orient='v', x = 'year of last review', y = 'adjusted_price')
plt.title('Years of last review and price')
plt.show()

# %%
popular_property_types = list(df_train['property_type'].value_counts()[df_train['property_type'].value_counts() > 50].index)
popular_property_types
# Out:
# ['Private room in house',
#  'Entire house',
#  'Private room in apartment',
#  'Private room in townhouse',
#  'Entire apartment',
#  'Entire guesthouse',
#  'Private room in villa',
#  'Private room in bungalow',
#  'Room in boutique hotel',
#  'Entire guest suite',
#  'Private room in condominium',
#  'Entire condominium',
#  'Private room in guest suite',
#  'Entire bungalow',
#  'Entire townhouse',
#  'Private room in guesthouse',
#  'Shared room in house',
#  'Entire villa',
#  'Private room in bed and breakfast',
#  'Private room in castle',
#  'Private room in tent',
#  'Camper/RV',
#  'Shared room in townhouse',
#  'Entire cottage',
#  'Shared room in apartment',
#  'Room in hotel',
#  'Private room in tiny house',
#  'Shared room',
#  'Tiny house',
#  'Shared room in condominium',
#  'Private room in cottage',
#  'Entire place',
#  'Shared room in guesthouse',
#  'Shared room in tent',
#  'Private room in hut',
#  'Barn']

# %%
df_train['property_type'].value_counts()
# Out:
# Private room in house                38965
# Entire house                         11741
# Private room in apartment             7963
# Private room in townhouse             7730
# Entire apartment                      7603
# Entire guesthouse                     4968
# Private room in villa                 4949
# Private room in bungalow              4123
# Room in boutique hotel                3937
# Entire guest suite                    3859
# Private room in condominium           3065
# Entire condominium                    2277
# Private room in guest suite           2228
# Entire bungalow                       1952
# Entire townhouse                      1746
# Private room in guesthouse            1654
# Shared room in house                  1595
# Entire villa                          1475
# Private room in bed and breakfast     1101
# Private room in castle                 637
# Private room in tent                   624
# Camper/RV                              424
# Shared room in townhouse               421
# Entire cottage                         412
# Shared room in apartment               219
# Room in hotel                          216
# Private room in tiny house             211
# Shared room                            209
# Tiny house                             209
# Shared room in condominium             207
# Private room in cottage                206
# Entire place                           203
# Shared room in guesthouse              202
# Shared room in tent                    202
# Private room in hut                    196
# Barn                                   195
# Name: property_type, dtype: int64

# %%
df_train['room_type'].value_counts()
# Out:
# Private room       77805
# Entire home/apt    37064
# Shared room         3055
# Name: room_type, dtype: int64

# %%
df_train['neighbourhood_cleansed'].value_counts()
# Out:
# Arcadia              30390
# Temple City          23870
# El Monte             20414
# Monrovia             19668
# Baldwin Park          6300
# Mayflower Village     5824
# Duarte                4373
# Sierra Madre          3591
# North El Monte        2267
# Irwindale             1227
# Name: neighbourhood_cleansed, dtype: int64

# %%
df_train['review_scores_rating'].value_counts()
# Out:
# 5.00    25428
# 4.50     3811
# 4.00     3736
# 4.67     3602
# 4.86     2448
#         ...
# 2.67      197
# 4.48      194
# 3.77      193
# 4.40      193
# 4.37       63
# Name: review_scores_rating, Length: 80, dtype: int64

# %%
df_train[df_train['bathrooms_text'].isna()]
# Out:
#               id       scrape_id  \
# 210327  48336328  20210705235432
# 116847  https://a0.muscache.com/im/pictures/user/0a2dccfc-f158-4e9d-af9f-478430892bce.jpg?aki_policy=profile_small
# 210429  https://a0.muscache.com/im/pictures/user/dc92e281-26c8-4968-b545-f6f2dcf14b85.jpg?aki_policy=profile_small
# 184666  https://a0.muscache.com/im/pictures/user/c75cd04a-d5c8-4c5e-b8ae-0d4e293bd01d.jpg?aki_policy=profile_small
#
#        host_has_profile_pic host_identity_verified neighbourhood_cleansed  \
# 210327                 True                   True               El Monte
# 159405                 True                   True           Baldwin Park
# 210534                 True                   True               El Monte
# 166990                 True                   True                Arcadia
# 221960                 True                   True            Temple City
# ...                     ...                    ...                    ...
# 117111                 True                   True           Baldwin Park
# 117024                 True                   True           Baldwin Park
# 116847                 True                   True           Baldwin Park
# 210429                 True                   True               El Monte
# 184666                 True                   True      Mayflower Village
#
#         latitude  longitude          property_type        room_type  \
# 210327  34.09455 -118.00145                   Barn  Entire home/apt
# 159405  34.06391 -117.99210  Private room in house     Private room
# 210534  34.09455 -118.00145                   Barn  Entire home/apt
# 166990  34.12540 -118.06213  Private room in villa     Private room
# 221960  34.12028 -118.06753            Shared room      Shared room
# ...          ...        ...                    ...              ...
# 117111  34.08359 -117.96153      Entire guesthouse  Entire home/apt
# 117024  34.08359 -117.96153      Entire guesthouse  Entire home/apt
# 116847  34.08359 -117.96153      Entire guesthouse  Entire home/apt
# 210429  34.09455 -118.00145                   Barn  Entire home/apt
# 184666  34.11480 -118.01345   Private room in tent     Private room
#
#         accommodates  bathrooms_text  bedrooms  beds  \
# 210327             9             NaN       NaN   0.0
# 159405             1             NaN       1.0   NaN
# 210534             9             NaN       NaN   0.0
# 166990             2             NaN       NaN   1.0
# 221960             2             NaN       1.0   1.0
# ...              ...             ...       ...   ...
# 117111             1             NaN       1.0   1.0
# 117024             1             NaN       1.0   1.0
# 116847             1             NaN       1.0   1.0
# 210429             9             NaN       NaN   0.0
# 184666             1             NaN       NaN   1.0
#
#                                                                                                                                                                                                                                                                                                                                                                                    amenities  \
# 210327                                                                                                                                                                                                                                                                                             ["Essentials", "Hot water", "Kitchen", "Free street parking", "Free parking on premises"]
# 159405                                                                                                                                                                                                                                            ["First aid kit", "Wifi", "Security cameras on property", "Lock on bedroom door", "Carbon monoxide alarm", "Smoke alarm", "Kitchen", "TV"]
# 210534                                                                                                                                                                                                                                                                                             ["Essentials", "Hot water", "Kitchen", "Free street parking", "Free parking on premises"]
# 166990                                                                                                                                                                      ["Washer", "Wifi", "Hot water", "Kitchen", "Dryer", "Heating", "Hot tub", "Long term stays allowed", "Free parking on premises", "Air conditioning", "Hangers", "Pool", "Fire extinguisher", "Private entrance"]
# 221960                                                                                                                                                                                                                                                                                                                                                   ["Pool", "Long term stays allowed"]
# ...                                                                                                                                                                                                                                                                                                                                                                                      ...
# 117111  ["Microwave", "Security cameras on property", "Heating", "TV", "Extra pillows and blankets", "Hot water", "Dishes and silverware", "Essentials", "Free parking on premises", "Hangers", "Kitchen", "Laundromat nearby", "Portable fans", "Private entrance", "Wifi", "Refrigerator", "Single level home", "Bed linens", "Free street parking", "Lockbox", "Long term stays allowed"]
# 117024  ["Microwave", "Security cameras on property", "Heating", "TV", "Extra pillows and blankets", "Hot water", "Dishes and silverware", "Essentials", "Free parking on premises", "Hangers", "Kitchen", "Laundromat nearby", "Portable fans", "Private entrance", "Wifi", "Refrigerator", "Single level home", "Bed linens", "Free street parking", "Lockbox", "Long term stays allowed"]
# 116847  ["Microwave", "Security cameras on property", "Heating", "TV", "Extra pillows and blankets", "Hot water", "Dishes and silverware", "Essentials", "Free parking on premises", "Hangers", "Kitchen", "Laundromat nearby", "Portable fans", "Private entrance", "Wifi", "Refrigerator", "Single level home", "Bed linens", "Free street parking", "Lockbox", "Long term stays allowed"]
# 210429                                                                                                                                                                                                                                                                                             ["Essentials", "Hot water", "Kitchen", "Free street parking", "Free parking on premises"]
# 184666                                                                                                                                                                                      ["First aid kit", "Wifi", "Hair dryer", "Hot water", "Shampoo", "Iron", "Long term stays allowed", "Essentials", "Free parking on premises", "Hangers", "Fire extinguisher", "Private entrance"]
#
#         minimum_nights.x  maximum_nights.x  minimum_minimum_nights  \
# 210327                 1                 1                       1
# 159405                 1                 3                       1
# 210534                 1                 1                       1
# 166990                15              1125                      15
# 221960                30               365                      30
# ...                  ...               ...                     ...
# 117111                 2                28                       2
# 117024                 2                28                       2
# 116847                 2                28                       2
# 210429                 1                 1                       1
# 184666                 1                28                       1
#
#         maximum_minimum_nights  minimum_maximum_nights  \
# 210327                       1                       1
# 159405                       1                    1125
# 210534                       1                       1
# 166990                      15                    1125
# 221960                      30                     365
# ...                        ...                     ...
# 117111                       2                    1125
# 117024                       2                    1125
# 116847                       2                    1125
# 210429                       1                       1
# 184666                       1                    1125
#
#         maximum_maximum_nights  minimum_nights_avg_ntm  \
# 210327                       1                     1.0
# 159405                    1125                     1.0
# 210534                       1                     1.0
# 166990                    1125                    15.0
# 221960                     365                    30.0
# ...                        ...                     ...
# 117111                    1125                     2.0
# 117024                    1125                     2.0
# 116847                    1125                     2.0
# 210429                       1                     1.0
# 184666                    1125                     1.0
#
#         maximum_nights_avg_ntm  has_availability  availability_30  \
# 210327                       1              True                0
# 159405                    1125              True               30
# 210534                       1              True                0
# 166990                    1125              True               23
# 221960                     365              True               30
# ...                        ...               ...              ...
# 117111                    1125              True               25
# 117024                    1125              True               25
# 116847                    1125              True               25
# 210429                       1              True                0
# 184666                    1125              True                0
#
#         availability_60  availability_90  availability_365  number_of_reviews  \
# 210327                0                0                 0                  0
# 159405               60               90                90                  1
# 210534                0                0                 0                  0
# 166990               53               83               173                  0
# 221960               60               90               365                  0
# ...                 ...              ...               ...                ...
# 117111               55               85               360                  5
# 117024               55               85               360                  5
# 116847               55               85               360                  5
# 210429                0                0                 0                  0
# 184666                0                4               279                 12
#
#         number_of_reviews_ltm  number_of_reviews_l30d first_review  \
# 210327                      0                       0          NaN
# 159405                      0                       0   2020-02-09
# 210534                      0                       0          NaN
# 166990                      0                       0          NaN
# 221960                      0                       0          NaN
# ...                       ...                     ...          ...
# 117111                      1                       0   2019-06-15
# 117024                      1                       0   2019-06-15
# 116847                      1                       0   2019-06-15
# 210429                      0                       0          NaN
# 184666                     12                       0   2020-09-26
#
#        last_review  review_scores_rating  instant_bookable  \
# 210327         NaN                   NaN             False
# 159405  2020-02-09                   5.0             False
# 210534         NaN                   NaN             False
# 166990         NaN                   NaN             False
# 221960         NaN                   NaN             False
# ...            ...                   ...               ...
# 117111  2021-05-06                   4.0             False
# 117024  2021-05-06                   4.0             False
# 116847  2021-05-06                   4.0             False
# 210429         NaN                   NaN             False
# 184666  2021-02-15                   4.0              True
#
#         calculated_host_listings_count  \
# 210327                               1
# 159405                               1
# 210534                               1
# 166990                               2
# 221960                               4
# ...                                ...
# 117111                               1
# 117024                               1
# 116847                               1
# 210429                               1
# 184666                              10
#
#         calculated_host_listings_count_entire_homes  \
# 210327                                            1
# 159405                                            0
# 210534                                            1
# 166990                                            1
# 221960                                            1
# ...                                             ...
# 117111                                            1
# 117024                                            1
# 116847                                            1
# 210429                                            1
# 184666                                            0
#
#         calculated_host_listings_count_private_rooms  \
# 210327                                             0
# 159405                                             1
# 210534                                             0
# 166990                                             1
# 221960                                             0
# ...                                              ...
# 117111                                             0
# 117024                                             0
# 116847                                             0
# 210429                                             0
# 184666                                             5
#
#         calculated_host_listings_count_shared_rooms  available  \
# 210327                                            0      False
# 159405                                            0      False
# 210534                                            0      False
# 166990                                            0      False
# 221960                                            3       True
# ...                                             ...        ...
# 117111                                            0       True
# 117024                                            0       True
# 116847                                            0       True
# 210429                                            0      False
# 184666                                            5       True
#
#         adjusted_price  minimum_nights.y  maximum_nights.y
# 210327           150.0                 1                 1
# 159405           115.0                 1              1125
# 210534           150.0                 1                 1
# 166990            80.0                15              1125
# 221960            60.0                30               365
# ...                ...               ...               ...
# 117111            69.0                 2              1125
# 117024            60.0                 2              1125
# 116847            59.0                 2              1125
# 210429           150.0                 1                 1
# 184666            30.0                 1              1125
#
# [1643 rows x 47 columns]

# %%
df_train['bathrooms_text'].value_counts()
# Out:
# 1.0    80461
# 1.5    19175
# 2.0    10506
# 2.5     2678
# 3.0     1393
# 0.0     1051
# 3.5      851
# 4.0      166
# Name: bathrooms_text, dtype: int64

# %%
df_train['host_has_profile_pic'].value_counts()
# Out:
# True     117622
# False       221
# Name: host_has_profile_pic, dtype: int64

# %%
years_of_host_since = pd.DataFrame({
    'year of host_since':pd.to_datetime(df_train['host_since'], format='%Y-%m-%d', errors='coerce').dt.year.fillna(0),
    'adjusted_price': df_train['adjusted_price']
})

plt.figure(figsize=(12,4))
sns.countplot(x="year of host_since", data=years_of_host_since)
plt.title('Row count')
plt.show()

plt.figure(figsize=(12,8))
sns.boxplot(data=years_of_host_since,orient='v', x = 'year of host_since', y = 'adjusted_price')
plt.title('Years of host_since and price')
plt.show()

# %%
#map

def create_map(neighbourhood_cleansed):
    price_view = lambda x: 'adjusted_price: ' + str(round(x, 2))

    if neighbourhood_cleansed in {'NYC', 'LA'}:
        fraction = 0.2
    else:
        fraction = 0.6
        
    df_temp = df_train[df_train['neighbourhood_cleansed'] == neighbourhood_cleansed].sample(frac=fraction,random_state=101)
    df_temp['adjusted_price'] = np.round(df_temp['adjusted_price'], 2)
    
    fig = px.scatter_mapbox(df_temp, 
                            lat="latitude", 
                            lon="longitude", 
                            hover_data=["adjusted_price"],
                            color='adjusted_price', 
                            zoom=10)
    
    fig.update_layout(
            title = f'Airbnb prices in {neighbourhood_cleansed}',
            geo_scope='usa',
            width=1000, 
            height=600,
            mapbox_style="white-bg",
            mapbox_layers=[{
                 "below": 'traces',
                 "sourcetype": "raster",
                 "sourceattribution": "United States Geological Survey",
                 "source": ["https://basemap.nationalmap.gov/arcgis/rest/services/USGSImageryOnly/MapServer/tile/{z}/{y}/{x}"]
              }]
    )
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.update_geos(fitbounds="locations")
    fig.show()
    
neighbourhood_cleansed = interact(lambda x: create_map(x), x=['NYC', 'LA', 'SF', 'DC', 'Chicago', 'Boston'])  #widget
create_map('LA')

# %%
sns.pairplot(df_train)

# %%
plt.figure(figsize = (36,36))
sns.heatmap(df_train.corr(),annot=True)

# %%
profile = ProfileReport(df_train)
profile.to_file(output_file="df_train.html")

# %% [markdown]
# # Data preparation

# %%
amenities_set = set()
for amenitie in df_train['amenities']:
    amenitie_set = set(re.sub(r'(\"|\{|\})', '', amenitie).split(','))
    for piece in amenitie_set:
        if "translation missing" not in piece and piece:
            amenities_set.add(piece.strip())
            
amenities_set
# Out:
# {'24\\ TV with Amazon Prime Video',
#  '30\\ TV with Roku',
#  '32\\ TV with Amazon Prime Video',
#  '42\\ HDTV with Amazon Prime Video',
#  '46\\ TV with Amazon Prime Video',
#  '48\\ HDTV with Chromecast',
#  '48\\ TV',
#  '50\\ HDTV with Netflix',
#  '50\\ TV',
#  '55\\ HDTV',
#  '55\\ HDTV with Netflix',
#  '55\\ HDTV with Roku',
#  '55\\ HDTV with premium cable',
#  '60\\ TV',
#  '60\\ TV with premium cable',
#  'Air conditioning',
#  'Air conditioning]',
#  'Alexa  Bluetooth sound system',
#  'Amazon Prime Video',
#  'Apple TV',
#  'BBQ grill',
#  'Baby bath',
#  'Baby safety gates',
#  'Babysitter recommendations',
#  'Backyard',
#  'Baking sheet',
#  'Baking sheet]',
#  'Barbecue utensils',
#  'Bathroom essentials',
#  'Bathtub',
#  'Beach essentials',
#  'Beachfront',
#  'Bed linens',
#  'Bedroom comforts',
#  'Bidet',
#  'Bikes',
#  'Board games',
#  'Body soap',
#  'Bose mobile speaker  Bluetooth sound system',
#  'Bread maker',
#  'Breakfast',
#  'Building staff',
#  'Cable TV',
#  'Carbon monoxide alarm',
#  'Ceiling fan',
#  'Central air conditioning',
#  'Central heating',
#  'Changing table',
#  'Children\\u2019s books and toys',
#  'Children\\u2019s dinnerware',
#  'Cleaning before checkout',
#  'Cleaning products',
#  'Clothing storage',
#  'Clothing storage: closet',
#  'Clothing storage: closet and dresser',
#  'Clothing storage: closet and walk-in closet',
#  'Clothing storage: dresser',
#  'Clothing storage: dresser and closet',
#  'Clothing storage: walk-in closet',
#  'Clothing storage: wardrobe and closet',
#  'Coffee maker',
#  'Coffee maker]',
#  'Conditioner',
#  'Conditioner]',
#  'Cooking basics',
#  'Crib',
#  'Dedicated workspace',
#  'Dedicated workspace: desk',
#  'Dedicated workspace: desk and office chair',
#  'Dedicated workspace: desk and table',
#  'Dedicated workspace: office chair',
#  'Dedicated workspace: table',
#  'Dedicated workspace: table and desk',
#  'Dedicated workspace]',
#  'Dining table',
#  'Dishes and silverware',
#  'Dishwasher',
#  'Dishwasher]',
#  'Dove body soap',
#  'Dryer',
#  'Dryer \\u2013 In building',
#  'Dryer \\u2013\\u00a0In unit',
#  'Drying rack for clothing',
#  'EV charger',
#  'Elevator',
#  'Essentials',
#  'Ethernet connection',
#  'Extra pillows and blankets',
#  'Fire extinguisher',
#  'Fire extinguisher]',
#  'Fire pit',
#  'Fireplace guards',
#  'First aid kit',
#  'Free carport on premises \\u2013 1 space',
#  'Free driveway parking on premises',
#  'Free driveway parking on premises \\u2013 1 space',
#  'Free driveway parking on premises \\u2013 2 spaces',
#  'Free driveway parking on premises \\u2013 30 spaces',
#  'Free dryer \\u2013 In building',
#  'Free dryer \\u2013 In unit',
#  'Free parking on premises',
#  'Free parking on premises]',
#  'Free residential garage on premises \\u2013 3 spaces',
#  'Free street parking',
#  'Free washer \\u2013 In building',
#  'Free washer \\u2013 In unit',
#  'Freezer',
#  'Fridge is in the garage downstairs near your room  refrigerator',
#  'Fridgidaire refrigerator',
#  'Full kitchen',
#  'GE gas stove',
#  'GE oven',
#  'Game console',
#  'Game console: Xbox 360 and Xbox One',
#  'Gas stove',
#  'General Electric stainless steel electric stove',
#  'General Electric stainless steel oven',
#  'Gym',
#  'Gym nearby',
#  'HBO Max',
#  'HDTV with Amazon Prime Video',
#  'Hair dryer',
#  'Hangers',
#  'Hangers]',
#  'Heating',
#  'Heating]',
#  'High chair',
#  'Host greets you',
#  'Hot tub',
#  'Hot water',
#  'Hot water kettle',
#  'Indoor fireplace',
#  'Induction stove',
#  'Insignia refrigerator',
#  'Iron',
#  'JBL sound system with Bluetooth and aux',
#  'Keurig coffee machine',
#  'Keypad',
#  'Kitchen',
#  'Kitchen]',
#  'Lake access',
#  'Lake access]',
#  'Laundromat nearby',
#  'Lock on bedroom door',
#  'Lockbox',
#  'Long term stays allowed',
#  'Long term stays allowed]',
#  'Luggage dropoff allowed',
#  'Microwave',
#  'Mini fridge',
#  'Mosquito net',
#  'Nespresso machine',
#  'Netflix',
#  'Organic body soap',
#  'Outdoor dining area',
#  'Outdoor furniture',
#  'Outdoor shower]',
#  'Outlet covers',
#  'Oven',
#  'Pack \\u2019n Play/travel crib',
#  'Paid dryer \\u2013 In building',
#  'Paid parking lot on premises \\u2013 1 space',
#  'Paid parking off premises',
#  'Paid parking on premises',
#  'Paid street parking off premises',
#  'Paid washer \\u2013 In building',
#  'Pantene Pro-V conditioner',
#  'Pantene Pro-V shampoo',
#  'Pantene conditioner',
#  'Pantene shampoo',
#  'Patio or balcony',
#  'Patio or balcony]',
#  'Piano',
#  'Ping pong table',
#  'Pocket wifi',
#  'Pool',
#  'Portable air conditioning',
#  'Portable fans',
#  'Portable fans]',
#  'Portable heater',
#  'Pour-over coffee',
#  'Private entrance',
#  'Private entrance]',
#  'Private fenced garden or backyard',
#  'Private garden or backyard',
#  'Private outdoor pool',
#  'Private patio or balcony',
#  'Private pool',
#  'Progettato shampoo',
#  'Radiant heating',
#  'Refrigerator',
#  'Rice maker',
#  'Roku',
#  'Room-darkening shades',
#  'SAMSUNG refrigerator',
#  'Safe',
#  'Security cameras on property',
#  'Self check-in',
#  'Shampoo',
#  'Shampoo]',
#  'Shared gym nearby',
#  'Shared outdoor pool',
#  'Shared patio or balcony',
#  'Shower gel',
#  'Single level home',
#  'Ski-in/Ski-out',
#  'Smart lock',
#  'Smart lock]',
#  'Smoke alarm',
#  'Smoke alarm]',
#  'Sony  sound system with Bluetooth and aux',
#  'Sound system',
#  'Sound system with Bluetooth and aux',
#  'Stainless steel electric stove',
#  'Stainless steel gas stove',
#  'Stainless steel oven',
#  'Stainless steel stove',
#  'Stove',
#  'Suave Men Citrus Rush 3-in-1 Shampoo Conditioner Body Wash conditioner',
#  'Suave Men Citrus Rush 3-in-1 Shampoo Conditioner Body Wash shampoo',
#  'TV',
#  'TV with Amazon Prime Video',
#  'TV with Netflix',
#  'TV with Roku',
#  'TV with standard cable',
#  'TV with standard cable]',
#  'TV]',
#  'Table corner guards',
#  'Toaster',
#  'Trash compactor',
#  'Washer',
#  'Washer \\u2013\\u00a0In building',
#  'Washer \\u2013\\u00a0In building]',
#  'Waterfront',
#  'Waterfront]',
#  'Wifi',
#  'Wifi \\u2013 100 Mbps',
#  'Wifi \\u2013 200 Mbps',
#  'Wifi \\u2013 220 Mbps',
#  'Wifi \\u2013 260 Mbps',
#  'Wifi \\u2013 50 Mbps',
#  'Wifi \\u2013 80 Mbps]',
#  'Window AC unit',
#  'Window guards',
#  'Wine glasses',
#  'World Amenities body soap',
#  'World Amenities conditioner',
#  'World Amenities shampoo',
#  'World Ammenities body soap',
#  'World Ammenities conditioner',
#  '[Clothing storage',
#  '[Clothing storage: dresser',
#  '[Clothing storage: wardrobe',
#  '[Dedicated workspace: office chair',
#  '[Dining table',
#  '[Drying rack for clothing',
#  '[Essentials',
#  '[Extra pillows and blankets',
#  '[First aid kit',
#  '[Hair dryer',
#  '[Heating',
#  '[Keypad',
#  '[Kitchen',
#  '[Long term stays allowed',
#  '[Long term stays allowed]',
#  '[Microwave',
#  '[Oven',
#  '[Pack \\u2019n Play/travel crib',
#  '[Pool',
#  '[Private entrance]',
#  '[Security cameras on property',
#  '[Shared garden or backyard',
#  '[Shared pool',
#  '[Toaster',
#  '[Washer',
#  '[Wifi',
#  '[standard body soap',
#  'and desk',
#  'and dresser',
#  'and office chair',
#  'and table',
#  'and walk-in closet',
#  'and wardrobe',
#  'closet',
#  'desk',
#  'dresser',
#  'mini fridge refrigerator',
#  'neutrogena body soap',
#  'office chair',
#  'premium cable',
#  'standard cable',
#  'standard conditioner',
#  'table',
#  'toaster oven stainless steel oven',
#  'walk-in closet',
#  'whirlpool refrigerator'}

# %%
sns.pairplot(df_train)

# %%
profile = ProfileReport(df_train)
profile.to_file(output_file="df_train-amenities.html")

# %%
def dummification(df):
    dummy_df = pd.DataFrame()
    object_cols = ['property_type', 'room_type', 'neighbourhood_cleansed', 'first_review']
    for col in object_cols:
        dummy_df = pd.concat([dummy_df, create_dummy(col, df)], axis = 1)
    
    return pd.concat([df.drop(columns = object_cols), dummy_df], axis = 1)
        
def create_dummy(col, df):
    df_dummy = pd.get_dummies(df[col], drop_first = True)
    df_dummy.columns = ['dum: ' + col + ': ' + name for name in df_dummy.columns]
    return df_dummy

def dum_col_filling(main_col_val, dum_col_name, main_col_name):
    if dum_col_name.replace(main_col_name + ': ', '') in main_col_val:
        return 1
    else:
        return 0

def set_to_dummies(df, column_name):
    all_values_of_sets = amenities_set
    dummy_columns_name = [column_name + ': ' + dum_col for dum_col in all_values_of_sets if dum_col]
    dummy_df = pd.DataFrame(0, index=df.index, columns=dummy_columns_name)
    df = pd.concat([dummy_df, df], axis = 1)
    for dum_col_name in dummy_columns_name:
        for i in df.index:
            df[dum_col_name][i] = dum_col_filling(df[column_name][i], dum_col_name, column_name)
    return df

def property_type_proc(val):
    if val in popular_property_types:
        return val
    else:
        return 'other'
      
def first_review_poc(val):
    if pd.isna(val):
        return 'no data'
    elif datetime.strptime(val,'%Y-%m-%d').year < 2014:
        return ' < 2014'
    else:
        return str(int(datetime.strptime(val,'%Y-%m-%d').year))
    
def unknown_filling(val):
    if pd.isna(val):
        return 'no data'
    else:
        return val

def host_since_proc(val):
    if pd.isna(val):
        return 2008
    else:
        return int(datetime.strptime(val,'%Y-%m-%d').year)

def true_to_1(val):
    if val in {'True', True, 't'}:
        return 1
    else:
        return 0
    
def processing(df):
    df = df.copy()
    df['property_type'] = df['property_type'].apply(property_type_proc)
    df['first_review'] = df['first_review'].apply(first_review_poc)
    df['neighbourhood_cleansed'] = df['neighbourhood_cleansed'].apply(unknown_filling)
    df['review_scores_rating'] = df['review_scores_rating'].fillna(0)
    df['bathrooms_text'] = df['bathrooms_text'].fillna(-1)
    df['bedrooms'] = df['bedrooms'].fillna(-1)
    df['beds'] = df['beds'].fillna(-1)
    df['host_has_profile_pic'] = df['host_has_profile_pic'].fillna('f')
    df['host_identity_verified'] = df['host_identity_verified'].fillna('f')
    df['host_since'] = df['host_since'].apply(host_since_proc)
    df['host_has_profile_pic'] = df['host_has_profile_pic'].apply(true_to_1)
    df['host_identity_verified'] = df['host_identity_verified'].apply(true_to_1)
    df['instant_bookable'] = df['instant_bookable'].apply(true_to_1)
    df = set_to_dummies(df, 'amenities')
    df = dummification(df)
    df.drop(['amenities', 'host_thumbnail_url', 'description', 'id', 'last_review', 'name'], axis = 1, inplace = True)
    return df.sort_index(ascending=False, axis=1)

#df_d = processing(df.sample(frac=0.01,random_state=101))
df_d = processing(df_train)
df_d
# Out:
# <ipython-input-33-920826ac3d24>:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              scrape_id  review_scores_rating  number_of_reviews_ltm  \
# 204766  20210705235432                  5.00                     14
# 58591   20210705235432                  4.42                      3
# 193071  20210705235432                  4.33                     15
# 131592  20210705235432                  0.00                      0
# 207706  20210705235432                  5.00                      1
# ...                ...                   ...                    ...
# 130051  20210705235432                  5.00                      1
# 140071  20210705235432                  0.00                      0
# 9299    20210705235432                  0.00                      0
# 160177  20210705235432                  5.00                      0
# 59795   20210705235432                  4.68                      3
#
#         number_of_reviews_l30d  number_of_reviews  minimum_nights_avg_ntm  \
# 204766                       4                 14                     3.9
# 58591                        0                 24                    14.0
# 193071                       0                 15                     1.0
# 131592                       0                  0                    20.0
# 207706                       1                  1                    30.0
# ...                        ...                ...                     ...
# 130051                       1                  7                     1.0
# 140071                       0                  0                     1.0
# 9299                         0                  0                     1.0
# 160177                       0                  4                     1.0
# 59795                        0                 22                    30.0
#
#         minimum_nights.y  minimum_nights.x  minimum_minimum_nights  \
# 204766                 4                 4                       3
# 58591                 14                14                      14
# 193071                 1                 1                       1
# 131592                20                20                      20
# 207706                30                30                      30
# ...                  ...               ...                     ...
# 130051                 1                 1                       1
# 140071                 1                 1                       1
# 9299                   1                 1                       1
# 160177                 1                 1                       1
# 59795                 30                30                      30
#
#         minimum_maximum_nights  maximum_nights_avg_ntm  maximum_nights.y  \
# 204766                    1125                    1125              1125
# 58591                     1125                    1125              1125
# 193071                      28                      28                28
# 131592                    1125                    1125              1125
# 207706                     365                     365               365
# ...                        ...                     ...               ...
# 130051                      10                      10                10
# 140071                    1125                    1125              1125
# 9299                      1125                    1125              1125
# 160177                    1125                    1125              1125
# 59795                      365                     365               365
#
#         maximum_nights.x  maximum_minimum_nights  maximum_maximum_nights  \
# 204766                60                       4                    1125
# 58591               1125                      14                    1125
# 193071                28                       1                      28
# 131592              1125                      20                    1125
# 207706               365                      30                     365
# ...                  ...                     ...                     ...
# 130051                10                       1                      10
# 140071              1125                       1                    1125
# 9299                1125                       1                    1125
# 160177              1125                       1                    1125
# 59795                365                      30                     365
#
#         longitude  latitude  instant_bookable  host_since  \
# 204766 -118.00170  34.15642                 1        2017
# 58591  -118.06145  34.12522                 0        2017
# 193071 -118.07197  34.09550                 1        2020
# 131592 -118.00889  34.11139                 1        2019
# 207706 -118.02444  34.14549                 0        2021
# ...           ...       ...               ...         ...
# 130051 -117.97402  34.07635                 0        2016
# 140071 -118.00958  34.13311                 0        2019
# 9299   -117.99315  34.15341                 0        2015
# 160177 -118.02365  34.11003                 0        2019
# 59795  -118.01209  34.07404                 0        2016
#
#         host_identity_verified    host_id  host_has_profile_pic  \
# 204766                       1  123539990                     1
# 58591                        0  114273547                     1
# 193071                       1  371816666                     1
# 131592                       0  277201385                     1
# 207706                       1  387700483                     1
# ...                        ...        ...                   ...
# 130051                       1   58250315                     1
# 140071                       1  297385781                     1
# 9299                         0   39764554                     1
# 160177                                             1
# 59795                                              2
#
#         calculated_host_listings_count_entire_homes  \
# 204766                                            5
# 58591                                             1
# 193071                                            0
# 131592                                            1
# 207706                                            0
# ...                                             ...
# 130051                                            0
# 140071                                            0
# 9299                                              0
# 160177                                            2
# 59795                                             0
#
#         calculated_host_listings_count  beds  bedrooms  bathrooms_text  \
# 204766                               5   2.0       1.0             1.0
# 58591                                1   4.0       2.0             2.5
# 193071                              11   1.0       1.0             1.0
# 131592                               1   4.0       4.0             3.5
# 207706                               3   2.0       1.0             1.5
# ...                                ...   ...       ...             ...
# 130051                               1   1.0       1.0             1.5
# 140071                               4   1.0      -1.0             1.5
# 9299                                 1   1.0       1.0             1.0
# 160177                               3   1.0       1.0             1.0
# 59795                                2   2.0       1.0             1.0
#
#         available  availability_90  availability_60  availability_365  \
# 204766       True               47               17               314
# 58591       False               34                4                34
# 193071      False               88               58               178
# 131592      False                0                0                 0
# 207706       True               74               44               101
# ...           ...              ...              ...               ...
# 130051      False               84               54                84
# 140071      False                0                0                 0
# 9299         True               90               60               365
# 160177      False                0                0                 0
# 59795        True               87               57               362
#
#         availability_30  amenities: whirlpool refrigerator  \
# 204766                4                                  0
# 58591                 0                                  0
# 193071               28                                  0
# 131592                0                                  0
# 207706               14                                  0
# ...                 ...                                ...
# 130051               24                                  0
# 140071                0                                  0
# 9299                 30                                  0
# 160177                0                                  0
# 59795                27                                  0
#
#         amenities: walk-in closet  \
# 204766                          0
# 58591                           0
# 193071                          0
# 131592                          0
# 207706                          0
# ...                           ...
# 130051                          0
# 140071                          0
# 9299                            0
# 160177                          0
# 59795                           0
#
#         amenities: toaster oven stainless steel oven  amenities: table  \
# 204766                                             0                 1
# 58591                                              0                 0
# 193071                                             0                 0
# 131592                                             0                 0
# 207706                                             0                 0
# ...                                              ...               ...
# 130051                                             0                 0
# 140071                                             0                 0
# 9299                                               0                 0
# 160177                                             0                 0
# 59795                                              0                 0
#
#         amenities: standard conditioner  amenities: standard cable  \
# 204766                                0                          1
# 58591                                 0                          0
# 193071                                0                          0
# 131592                                0                          0
# 207706                                0                          0
# ...                                 ...                        ...
# 130051                                0                          0
# 140071                                0                          0
# 9299                                  0                          0
# 160177                                0                          0
# 59795                                 0                          0
#
#         amenities: premium cable  amenities: office chair  \
# 204766                         0                        0
# 58591                          0                        0
# 193071                         0                        0
# 131592                         0                        0
# 207706                         0                        0
# ...                          ...                      ...
# 130051                         0                        0
# 140071                         0                        0
# 9299                           0                        0
# 160177                         0                        0
# 59795                          0                        0
#
#         amenities: neutrogena body soap  amenities: mini fridge refrigerator  \
# 204766                                0                                    0
# 58591                                 0                                    0
# 193071                                0                                    0
# 131592                                0                                    0
# 207706                                0                                    0
# ...                                 ...                                  ...
# 130051                                0                                    0
# 140071                                0                                    0
# 9299                                  0                                    0
# 160177                                0                                    0
# 59795                                 0                                    0
#
#         amenities: dresser  amenities: desk  amenities: closet  \
# 204766                   0                1                  1
# 58591                    0                0                  0
# 193071                   0                0                  0
# 131592                   0                0                  0
#
#         amenities: 42\ HDTV with Amazon Prime Video  \
# 204766                                            0
# 58591                                             0
# 193071                                            0
# 131592                                            0
# 207706                                            0
# ...                                             ...
# 130051                                            0
# 140071                                            0
# 9299                                              0
# 160177                                            0
# 59795                                             0
#
#         amenities: 32\ TV with Amazon Prime Video  \
# 204766                                          0
# 58591                                           0
# 193071                                          0
# 131592                                          0
# 207706                                          0
# ...                                           ...
# 130051                                          0
# 140071                                          0
# 9299                                            0
# 160177                                          0
# 59795                                           0
#
#         amenities: 30\ TV with Roku  \
# 204766                            0
# 58591                             0
# 193071                            0
# 131592                            0
# 207706                            0
# ...                             ...
# 130051                            0
# 140071                            0
# 9299                              0
# 160177                            0
# 59795                             0
#
#         amenities: 24\ TV with Amazon Prime Video  adjusted_price  \
# 204766                                          0           147.0
# 58591                                           0           130.0
# 193071                                          0            75.0
# 131592                                          0           179.0
# 207706                                          0            45.0
# ...                                           ...             ...
# 130051                                          0            34.0
# 140071                                          0            40.0
# 9299                                            0           150.0
# 160177                                          0            48.0
# 59795                                           0            50.0
#
#         accommodates
# 204766             4
# 58591              5
# 193071             2
# 131592             8
# 207706             3
# ...              ...
# 130051             1
# 140071             2
# 9299               2
# 160177             2
# 59795              3
#
# [117924 rows x 387 columns]

# %%
df_d[df_d.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [scrape_id, review_scores_rating, number_of_reviews_ltm, number_of_reviews_l30d, number_of_reviews, minimum_nights_avg_ntm, minimum_nights.y, minimum_nights.x, minimum_minimum_nights, minimum_maximum_nights, maximum_nights_avg_ntm, maximum_nights.y, maximum_nights.x, maximum_minimum_nights, maximum_maximum_nights, longitude, latitude, instant_bookable, host_since, host_identity_verified, host_id, host_has_profile_pic, has_availability, dum: room_type: Shared room, dum: room_type: Private room, dum: property_type: Tiny house, dum: property_type: Shared room in townhouse, dum: property_type: Shared room in tent, dum: property_type: Shared room in house, dum: property_type: Shared room in guesthouse, dum: property_type: Shared room in condominium, dum: property_type: Shared room in apartment, dum: property_type: Shared room, dum: property_type: Room in hotel, dum: property_type: Room in boutique hotel, dum: property_type: Private room in villa, dum: property_type: Private room in townhouse, dum: property_type: Private room in tiny house, dum: property_type: Private room in tent, dum: property_type: Private room in hut, dum: property_type: Private room in house, dum: property_type: Private room in guesthouse, dum: property_type: Private room in guest suite, dum: property_type: Private room in cottage, dum: property_type: Private room in condominium, dum: property_type: Private room in castle, dum: property_type: Private room in bungalow, dum: property_type: Private room in bed and breakfast, dum: property_type: Private room in apartment, dum: property_type: Entire villa, dum: property_type: Entire townhouse, dum: property_type: Entire place, dum: property_type: Entire house, dum: property_type: Entire guesthouse, dum: property_type: Entire guest suite, dum: property_type: Entire cottage, dum: property_type: Entire condominium, dum: property_type: Entire bungalow, dum: property_type: Entire apartment, dum: property_type: Camper/RV, dum: neighbourhood_cleansed: Temple City, dum: neighbourhood_cleansed: Sierra Madre, dum: neighbourhood_cleansed: North El Monte, dum: neighbourhood_cleansed: Monrovia, dum: neighbourhood_cleansed: Mayflower Village, dum: neighbourhood_cleansed: Irwindale, dum: neighbourhood_cleansed: El Monte, dum: neighbourhood_cleansed: Duarte, dum: neighbourhood_cleansed: Baldwin Park, dum: first_review: no data, dum: first_review: 2021, dum: first_review: 2020, dum: first_review: 2019, dum: first_review: 2018, dum: first_review: 2017, dum: first_review: 2016, dum: first_review: 2015, calculated_host_listings_count_shared_rooms, calculated_host_listings_count_private_rooms, calculated_host_listings_count_entire_homes, calculated_host_listings_count, beds, bedrooms, bathrooms_text, available, availability_90, availability_60, availability_365, availability_30, amenities: whirlpool refrigerator, amenities: walk-in closet, amenities: toaster oven stainless steel oven, amenities: table, amenities: standard conditioner, amenities: standard cable, amenities: premium cable, amenities: office chair, amenities: neutrogena body soap, amenities: mini fridge refrigerator, amenities: dresser, ...]
# Index: []

# %%
sns.pairplot(df_d)

# %%
profile = ProfileReport(df_d)
profile.to_file(output_file="df_d.html")

# %% [markdown]
# # Modelling

# %%
#adding missing columns to test \ validation sets and deleting unnecessary
columns_needed = set(df_d.columns)
def columns_standardization(df):
    df = df.copy()
    for col in columns_needed:
        if col not in set(df.columns):
            df.insert(loc = len(df.columns), column = col, value = 0, allow_duplicates=False)
    
    for col in set(df.columns):
        if col not in columns_needed:
            df.drop(columns = col, axis = 1, inplace = True)
    
    return df.sort_index(ascending=False, axis=1)

# %%
test = columns_standardization(processing(df_test))
test

# %%
test[test.isnull().any(axis=1)]

# %%
def show_metrics(prediction_test, prediction_train, y_test, y_train):
    MAE = round(metrics.mean_absolute_error(y_test, prediction_test), 2)
    MSE = round(metrics.mean_squared_error(y_test, prediction_test), 2)
    RMSE = round(np.sqrt(metrics.mean_squared_error(y_test, prediction_test)), 2)
    RMSE_ratio_test= round(np.sqrt(metrics.mean_squared_error(y_test, prediction_test)) / np.mean(y_test),3)
    RMSE_ratio_train = round(np.sqrt(metrics.mean_squared_error(y_train, prediction_train)) / np.mean(y_train),3)
    R_2_test = round(metrics.explained_variance_score(y_test, prediction_test), 2)
    R_2_train = round(metrics.explained_variance_score(y_train, prediction_train), 2)
    
    metrics_data = pd.DataFrame(data = [MAE, MSE, RMSE, RMSE_ratio_test, 
                                    RMSE_ratio_train, R_2_test, R_2_train]).T
    
    metrics_data.columns = ['MAE', 'MSE', 'RMSE', 'RMSE_ratio_test', 
                                    'RMSE_ratio_train', 'R_2_test', 'R_2_train']
    display(metrics_data)
           


def analysis(model, X_train, X_test, y_train, y_test):
    
    prediction_test = model.predict(X_test)
    prediction_train = model.predict(X_train)
        
    
    show_metrics(prediction_test, prediction_train, y_test, y_train)
    
    sns.regplot(x = y_test, y = prediction_test, fit_reg=False)
    plt.title('Prediction and real')
    plt.show()

    sns.distplot(y_test - prediction_test, bins = 50)
    plt.title('Error variance')
    plt.show()

# %%
df_d.info(verbose=True)

# %%
df_d

# %%
plt.figure(figsize=(140,70))
sns.heatmap(df_d.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
#df_d = df_d[df_d['adjusted_price'].notna()]

# %%
#test = test[test['adjusted_price'].notna()]

# %%
#df_d['adjusted_price'].unique()

# %%
#test['adjusted_price'].unique()

# %%
df_d.isnull().sum(axis = 0).sort_values(ascending = False).head(60)

# %%
test.isnull().sum(axis = 0).sort_values(ascending = True).head(60)

# %%
lm = LinearRegression(
        n_jobs = -1,
        normalize = True
)

lm.fit(df_d.drop('adjusted_price', axis = 1), df_d['adjusted_price'])

comment = ''

analysis(
    model = lm, 
    X_train = df_d.drop('adjusted_price', axis = 1), 
    X_test = test.drop('adjusted_price', axis = 1), 
    y_train = df_d['adjusted_price'], 
    y_test = test['adjusted_price']
)

# %%
#plt.figure(figsize=(140,70))
#sns.heatmap(test.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
rfm = RandomForestRegressor(
          max_depth = 10,
          n_jobs = -1, 
          random_state = 101,
          n_estimators = 700
    
)
rfm.fit(df_d.drop('adjusted_price', axis = 1), df_d['adjusted_price'])

comment = ''

analysis(
    model = rfm, 
    X_train = df_d.drop('adjusted_price', axis = 1), 
    X_test = test.drop('adjusted_price', axis = 1), 
    y_train = df_d['adjusted_price'], 
    y_test = test['adjusted_price']
)

# %%
gbr_model = GradientBoostingRegressor(random_state = 101)
gbr_model.fit(df_d.drop('adjusted_price', axis = 1), df_d['adjusted_price'])

comment = ''

analysis(
    model = gbr_model, 
    X_train = df_d.drop('adjusted_price', axis = 1), 
    X_test = test.drop('adjusted_price', axis = 1), 
    y_train = df_d['adjusted_price'], 
    y_test = test['adjusted_price']
)

# %% [markdown]
# # Dense neural models

# %%
#scaling
scaler = MinMaxScaler()
scaler.fit(df_d.drop('adjusted_price', axis = 1))
X_train_sc = scaler.transform(df_d.drop('adjusted_price', axis = 1).values)
X_test_sc = scaler.transform(test.drop('adjusted_price', axis = 1).values)
y_train = df_d['adjusted_price'].values
y_test = test['adjusted_price'].values

# %%
nn_model1 = Sequential()


es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)


nn_model1.add(Dense(64, activation = 'relu'))
nn_model1.add(Dropout(0.1))
nn_model1.add(Dense(1))

nn_model1.compile(
    optimizer='rmsprop',
    loss='mse'
)

nn_model1.fit(
    x = X_train_sc,
    y = y_train,
    epochs = 100,
    validation_data=(X_test_sc, y_test), 
    batch_size = 128,
    callbacks=[es]
)


pd.DataFrame(nn_model1.history.history).plot()
plt.show()

analysis(model = nn_model1, 
         X_train = X_train_sc, 
         X_test = X_test_sc, 
         y_train = y_train, 
         y_test = y_test)

# %% [markdown]
# # Using text data from 'description' column

# %%
df_train['description']

# %%
def del_punct(text):
    chars = [char for char in text if char not in string.punctuation]
    return ''.join(chars)

def del_stopwords(text):
    words = [word for word in text.split() if word.lower() not in stopwords.words('english')]
    return words

def text_preparation(text):
    text = text.lower()
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'\d+', 'somenumbers', text)
    text = del_stopwords(del_punct(text))
    return text
    
    
text_preparation('Enjoy a beautiful 67 contemporary residence with')

# %%
df_train['description']= df_train['description'].values.astype('U')

# %%
df_test['description']= df_test['description'].values.astype('U')

# %%
bow_transformer = CountVectorizer(analyzer = text_preparation, max_features = 1500).fit(df_train['description'])
bow = bow_transformer.transform(df_train['description'])
bow.shape

# %%
tfidf_transformer = TfidfTransformer().fit(bow)
train_tfidf = tfidf_transformer.transform(bow)

bow_test = bow_transformer.transform(df_test['description'])
test_tfidf = tfidf_transformer.transform(bow_test)

# %%
rfm_text = RandomForestRegressor(
    max_depth = 10, 
    n_estimators = 500,
    n_jobs = -1, 
    random_state = 101
)
rfm_text.fit(train_tfidf, df_train['adjusted_price'])

comment = ''

analysis(
    model = rfm_text, 
    X_train = train_tfidf, 
    X_test = test_tfidf, 
    y_train = df_train['adjusted_price'], 
    y_test = df_test['adjusted_price']
)

# %% [markdown]
# # We can see that there is not much information in description of object, that can be used for price prediction, but we can try use this in general model. As an experiment we can try to create a model, that would we a stack of 2 models - prediction of text model will be used in model built on all available features as one more feature.

# %%
class StackRegression:
    
    def __init__(self, model_general, model_secondary):
        self.model_general = model_general
        self.model_secondary = model_secondary
    
    def fit_predict(self, X_train_general, X_train_secondary, y_train, X_test_general, X_test_secondary, y_test):
        self.model_secondary.fit(X_train_secondary, y_train)
        
        self.secondary_predictions_test =  self.model_secondary.predict(X_test_secondary)
        self.secondary_predictions_train =  self.model_secondary.predict(X_train_secondary)
        
        self.X_train_full = X_train_general.copy()
        self.X_train_full.assign(secondary_model_predictions = self.secondary_predictions_train)
        
        self.X_test_full = X_test_general.copy()
        self.X_test_full.assign(secondary_model_predictions = self.secondary_predictions_test)
                        
        self.model_general.fit(self.X_train_full, y_train)
        
        return self.model_general.predict(self.X_test_full)

# %%
model_general = RandomForestRegressor(
          max_depth = 10,
          n_jobs = -1, 
          random_state = 101,
          n_estimators = 700
    
)

model_for_text = RandomForestRegressor(
          max_depth = 10,
          n_jobs = -1, 
          random_state = 101,
          n_estimators = 700
    
)

stack_model = StackRegression(model_general, model_for_text)


prediction_test = stack_model.fit_predict(
    X_train_general = df_d.drop('adjusted_price', axis = 1), 
    X_train_secondary = train_tfidf, 
    y_train = df_d['adjusted_price'], 
    X_test_general = test.drop('adjusted_price', axis = 1), 
    X_test_secondary = test_tfidf, 
    y_test = test['adjusted_price']
)

prediction_train = stack_model.fit_predict(
    X_train_general = df_d.drop('adjusted_price', axis = 1), 
    X_train_secondary = train_tfidf, 
    y_train = df_d['adjusted_price'], 
    X_test_general = df_d.drop('adjusted_price', axis = 1), 
    X_test_secondary = train_tfidf, 
    y_test = df_d['adjusted_price']
)

show_metrics(prediction_test, prediction_train, y_test = test['adjusted_price'], y_train = df_d['adjusted_price'])


sns.regplot(x = test['adjusted_price'], y = prediction_test, fit_reg=False)
plt.title('Prediction and real')
plt.show()

sns.distplot(test['adjusted_price'] - prediction_test, bins = 50)
plt.title('Error variance')
plt.show()

# %% [markdown]
# # This model doesn't have an advantage over more simple models. So for final submission I prefer to use just simple RFR

# %% [markdown]
# # Validation

# %%
val_data_for_model = columns_standardization(processing(validation_df))
val_data_for_model

# %%
val_data_for_model[val_data_for_model.isnull().any(axis=1)]

# %%
analysis(
    model = rfm, 
    X_train = df_d.drop('adjusted_price', axis = 1), 
    X_test = val_data_for_model.drop('adjusted_price', axis = 1), 
    y_train = df_d['adjusted_price'], 
    y_test = val_data_for_model['adjusted_price']
)
